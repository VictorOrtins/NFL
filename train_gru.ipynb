# %% [markdown]
# # Imports

# %%
import itertools
import os

import joblib
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf


from datetime import datetime

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder

from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Input, LSTM, Dense, TimeDistributed, Concatenate, Dropout, GRU
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam # Importar o otimizador Adam
# Out:
# 2025-10-02 14:30:44.078182: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-02 14:30:44.400858: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-02 14:30:45.949526: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %% [markdown]
# # Utils

# %% [markdown]
# ## Data Utils

# %%
def load_data(base_path, weeks, file_type='input'):
    all_dfs = []
    for week in weeks:
        file_name = f"{file_type}_2023_w{str(week).zfill(2)}.csv"
        file_path = os.path.join(base_path, file_name)
        if os.path.exists(file_path):
            df = pd.read_csv(file_path)
            df['week'] = week
            all_dfs.append(df)
    if not all_dfs: return pd.DataFrame()
    return pd.concat(all_dfs, ignore_index=True)

# %% [markdown]
# ## Feature Engineering Utils

# %%
def convert_height_to_inches(height_str):
    try:
        feet, inches = map(int, str(height_str).split('-'))
        return feet * 12 + inches
    except: return np.nan

def calculate_age(birth_date_str, current_date=datetime(2024, 1, 1)):
    try:
        birth_date = datetime.strptime(str(birth_date_str), '%Y-%m-%d')
        return (current_date - birth_date).days / 365.25
    except: return np.nan

def feature_engineering(df):
    df['player_height_inches'] = df['player_height'].apply(convert_height_to_inches)
    df['player_age'] = df['player_birth_date'].apply(calculate_age)
    df['dist_to_land_spot'] = np.sqrt((df['x'] - df['ball_land_x'])**2 + (df['y'] - df['ball_land_y'])**2)
    df['delta_x_to_land'] = df['ball_land_x'] - df['x']
    df['delta_y_to_land'] = df['ball_land_y'] - df['y']
    dir_rad = np.deg2rad(df['dir'])
    df['vx'] = df['s'] * np.cos(dir_rad)
    df['vy'] = df['s'] * np.sin(dir_rad)
    return df

# %% [markdown]
# ## Preprocessing Utils

# %%
def create_sequences(input_df, output_df, features_to_use, max_input_len, max_output_len, is_test=False):
    unique_plays = input_df[['game_id', 'play_id', 'nfl_id']].drop_duplicates()
    
    encoder_input_data = []
    decoder_output_data = [] # Apenas para treino/validação
    play_identifiers = [] # Para mapear previsões de volta

    for _, row in unique_plays.iterrows():
        game_id, play_id, nfl_id = row['game_id'], row['play_id'], row['nfl_id']
        
        input_seq = input_df[(input_df['game_id'] == game_id) & (input_df['play_id'] == play_id) & (input_df['nfl_id'] == nfl_id)]
        input_features = input_seq[features_to_use].values
        
        padded_input = np.zeros((max_input_len, len(features_to_use)))
        seq_len = min(len(input_features), max_input_len)
        padded_input[-seq_len:] = input_features[-seq_len:]
        encoder_input_data.append(padded_input)
        play_identifiers.append((game_id, play_id, nfl_id, input_seq['num_frames_output'].iloc[0]))
        
        if not is_test:
            output_seq = output_df[(output_df['game_id'] == game_id) & (output_df['play_id'] == play_id) & (output_df['nfl_id'] == nfl_id)]
            output_coords = output_seq[['x', 'y']].values
            
            padded_output = np.zeros((max_output_len, 2))
            seq_len_out = min(len(output_coords), max_output_len)
            if seq_len_out > 0:
                padded_output[:seq_len_out] = output_coords[:seq_len_out]
            decoder_output_data.append(padded_output)

    if is_test:
        return np.array(encoder_input_data), play_identifiers
    else:
        return np.array(encoder_input_data), np.array(decoder_output_data)

# %% [markdown]
# ## Model Utils

# %%
def build_seq2seq_model(input_shape, output_seq_len, latent_dim=128):
    encoder_inputs = Input(shape=input_shape, name='encoder_input')
    encoder_gru = GRU(latent_dim, return_state=True, name='encoder_gru')
    encoder_outputs, state_h = encoder_gru(encoder_inputs)
    encoder_states = [state_h]

    decoder_inputs = Input(shape=(None, 2), name='decoder_input_for_training')
    decoder_gru = GRU(latent_dim, return_sequences=True, return_state=True, name='decoder_gru')
    decoder_outputs, _ = decoder_gru(decoder_inputs, initial_state=encoder_states)

    decoder_dense = TimeDistributed(Dense(2, name='output_coords'), name='time_distributed_dense')
    decoder_outputs = decoder_dense(decoder_outputs)

    model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

    # Modelos de inferência
    encoder_model = Model(encoder_inputs, encoder_states)

    decoder_state_input_h = Input(shape=(latent_dim,))
    decoder_single_step_input = Input(shape=(1, 2))
    decoder_outputs_inf, state_h_inf = decoder_gru(decoder_single_step_input, initial_state=[decoder_state_input_h])
    decoder_outputs_inf = decoder_dense(decoder_outputs_inf)
    decoder_model = Model(
        [decoder_single_step_input, decoder_state_input_h],
        [decoder_outputs_inf, state_h_inf]
    )

    return model, encoder_model, decoder_model

# def build_seq2seq_model(input_shape, output_seq_len, latent_dim=128, dropout_rate=0.2):
#     """
#     Constrói o modelo Encoder-Decoder com LSTM, agora com Dropout.
#     """
#     # --- Encoder ---
#     encoder_inputs = Input(shape=input_shape, name='encoder_input')
#     encoder_lstm = GRU(latent_dim, return_state=True, name='encoder_lstm')
#     _, state_h, state_c = encoder_lstm(encoder_inputs)
#     encoder_states = [state_h, state_c]
    
#     # --- Decoder ---
#     decoder_inputs = Input(shape=(None, 2), name='decoder_input_for_training')
#     decoder_lstm = GRU(latent_dim, return_sequences=True, return_state=True, name='decoder_lstm')
#     decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
    
#     # Adicionando Dropout para regularização
#     decoder_outputs = Dropout(dropout_rate)(decoder_outputs)
    
#     decoder_dense = TimeDistributed(Dense(2, name='output_coords'), name='time_distributed_dense')
#     decoder_outputs = decoder_dense(decoder_outputs)

#     model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
    
#     return model

# %%
def run_training_pipeline(config):
    """Função principal que encapsula todo o processo de treinamento."""
    
    PROCESSED_DATA_PATH = 'processed_training_data.npz'

    # --- LÓGICA DE CARREGAMENTO ---
    # Verifica se os dados processados já existem
    if not os.path.exists(PROCESSED_DATA_PATH):
        print("Dados pré-processados não encontrados. Executando o pipeline completo...")
        # --- Carregamento de TODOS os dados de treino ---
        print("Carregando dados de treinamento (Semanas 1-18)...")
        input_df = load_data(config['BASE_PATH'], range(1, 19), 'input')
        output_df = load_data(config['BASE_PATH'], range(1, 19), 'output')
        
        # --- Engenharia de Atributos ---
        print("Executando engenharia de atributos...")
        input_df = feature_engineering(input_df)

        # --- Definição do Pré-processador ---
        numeric_features = ['x', 'y', 's', 'a', 'player_height_inches', 'player_age', 'dist_to_land_spot', 'delta_x_to_land', 'delta_y_to_land', 'vx', 'vy']
        categorical_features = ['play_direction', 'player_position', 'player_side', 'player_role']
        
        preprocessor = ColumnTransformer(
            transformers=[
                ('num', StandardScaler(), numeric_features),
                ('cat', OneHotEncoder(handle_unknown='ignore', sparse_output=False), categorical_features)
            ], remainder='drop'
        )
        
        # --- Divisão Treino/Validação por semana ---
        train_df = input_df[input_df['week'].isin(config['TRAIN_WEEKS'])]
        val_df = input_df[input_df['week'].isin(config['VALIDATION_WEEKS'])]
        
        # AJUSTAR ('fit') o preprocessor APENAS nos dados de treino
        print("Ajustando o pré-processador nos dados de treino...")
        preprocessor.fit(train_df[numeric_features + categorical_features])
        
        # Salvar o preprocessor para uso na inferência
        joblib.dump(preprocessor, 'preprocessor.joblib')
        
        # Aplicar a transformação
        processed_train_data = preprocessor.transform(train_df[numeric_features + categorical_features])
        processed_val_data = preprocessor.transform(val_df[numeric_features + categorical_features])
        
        feature_names = preprocessor.get_feature_names_out()
        
        processed_train_df = pd.DataFrame(processed_train_data, columns=feature_names, index=train_df.index)
        processed_val_df = pd.DataFrame(processed_val_data, columns=feature_names, index=val_df.index)
        
        id_cols = ['game_id', 'play_id', 'nfl_id', 'num_frames_output']
        final_train_df = pd.concat([train_df[id_cols], processed_train_df], axis=1)
        final_val_df = pd.concat([val_df[id_cols], processed_val_df], axis=1)

        # --- Criação de Sequências ---
        print("Criando sequências de treino e validação...")
        X_enc_train, y_dec_train = create_sequences(final_train_df, output_df, feature_names, config['MAX_INPUT_LEN'], config['MAX_OUTPUT_LEN'])
        X_enc_val, y_dec_val = create_sequences(final_val_df, output_df, feature_names, config['MAX_INPUT_LEN'], config['MAX_OUTPUT_LEN'])

        print(f"Salvando dados pré-processados em '{PROCESSED_DATA_PATH}'...")
        np.savez_compressed(
            PROCESSED_DATA_PATH,
            X_enc_train=X_enc_train,
            y_dec_train=y_dec_train,
            X_enc_val=X_enc_val,
            y_dec_val=y_dec_val
        )
        print("Dados salvos com sucesso para uso futuro.")
        
    else:
        print(f"Carregando dados pré-processados de '{PROCESSED_DATA_PATH}'...")
        processed_data = np.load(PROCESSED_DATA_PATH)
        X_enc_train = processed_data['X_enc_train']
        y_dec_train = processed_data['y_dec_train']
        X_enc_val = processed_data['X_enc_val']
        y_dec_val = processed_data['y_dec_val']
        print("Dados carregados com sucesso.") 
    
    # Input do decoder para teacher forcing
    dec_input_train = np.zeros_like(y_dec_train); dec_input_train[:, 1:, :] = y_dec_train[:, :-1, :]
    dec_input_val = np.zeros_like(y_dec_val); dec_input_val[:, 1:, :] = y_dec_val[:, :-1, :]

    # --- Construção e Treinamento do Modelo ---
    input_shape = X_enc_train.shape[1:]
    model, encoder_model, decoder_model = build_seq2seq_model(input_shape, config['MAX_OUTPUT_LEN'], config['LATENT_DIM'])
    model.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError()])
    model.summary()

    callbacks = [EarlyStopping(monitor='val_loss', patience=config['EARLY_STOPPING'], restore_best_weights=True), ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5)]
    
    print("\nIniciando o treinamento...")
    history = model.fit(
        [X_enc_train, dec_input_train], y_dec_train,
        batch_size=config['BATCH_SIZE'],
        epochs=config['EPOCHS'],
        validation_data=([X_enc_val, dec_input_val], y_dec_val),
        callbacks=callbacks
    )
    
    # Salvar os modelos de inferência
    encoder_model.save('encoder_model.h5')
    decoder_model.save('decoder_model.h5')
    
    print("Treinamento concluído e modelos salvos.")
    return model, history

# %%
def run_training_for_grid_search(config, X_enc_train, y_dec_train, X_enc_val, y_dec_val):
    """
    Função adaptada para rodar um único treinamento dentro do Grid Search.
    Ela constrói, compila e treina o modelo, retornando o melhor resultado.
    """
    # Limpa a sessão do Keras para garantir que os modelos não interfiram uns com os outros
    tf.keras.backend.clear_session()

    # --- Construção e Compilação do Modelo ---
    input_shape = X_enc_train.shape[1:]
    model = build_seq2seq_model(
        input_shape, 
        config['MAX_OUTPUT_LEN'], 
        latent_dim=config['LATENT_DIM'],
        dropout_rate=config['DROPOUT_RATE']
    )
    
    optimizer = Adam(learning_rate=config['LEARNING_RATE'])
    model.compile(optimizer=optimizer, loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError()])
    
    # --- Preparação dos Dados do Decoder ---
    dec_input_train = np.zeros_like(y_dec_train); dec_input_train[:, 1:, :] = y_dec_train[:, :-1, :]
    dec_input_val = np.zeros_like(y_dec_val); dec_input_val[:, 1:, :] = y_dec_val[:, :-1, :]
    
    # --- Treinamento ---
    # Usamos EarlyStopping para parar o treino quando a perda de validação não melhora
    callbacks = [
        EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True, verbose=1)
    ]

    print(f"\n--- Treinando com config: {config} ---")
    history = model.fit(
        [X_enc_train, dec_input_train], y_dec_train,
        batch_size=config['BATCH_SIZE'],
        epochs=config['EPOCHS'],
        validation_data=([X_enc_val, dec_input_val], y_dec_val),
        callbacks=callbacks,
        verbose=1 # Mudar para 0 ou 2 se quiser menos output
    )
    
    # Retorna a melhor pontuação de perda de validação encontrada durante o treino
    best_val_loss = min(history.history['val_loss'])
    return best_val_loss, history


# --- NOVA FUNÇÃO MESTRE PARA O GRID SEARCH ---

def run_grid_search(param_grid, epochs=100):
    """
    Orquestra o processo de Grid Search.
    """
    # --- 1. Definir o Espaço de Busca de Hiperparâmetros ---
   

    # --- 2. Carregar e Preparar os Dados (apenas uma vez) ---
    # Esta parte é a mesma do script anterior, carregando os dados do arquivo .npz
    PROCESSED_DATA_PATH = 'processed_training_data.npz'
    if not os.path.exists(PROCESSED_DATA_PATH):
        print("Erro: Arquivo de dados pré-processados não encontrado. Rode o pipeline de treinamento normal primeiro.")
        return

    print(f"Carregando dados pré-processados de '{PROCESSED_DATA_PATH}'...")
    processed_data = np.load(PROCESSED_DATA_PATH)
    X_enc_train = processed_data['X_enc_train']
    y_dec_train = processed_data['y_dec_train']
    X_enc_val = processed_data['X_enc_val']
    y_dec_val = processed_data['y_dec_val']
    print("Dados carregados com sucesso.")

    # --- 3. Iterar sobre as Combinações de Parâmetros ---
    results = []
    
    # Gera todas as combinações de parâmetros
    keys, values = zip(*param_grid.items())
    param_combinations = [dict(zip(keys, v)) for v in itertools.product(*values)]
    
    print(f"\nIniciando Grid Search com {len(param_combinations)} combinações.")

    for i, params in enumerate(param_combinations):
        print(f"\n--- Rodada {i+1}/{len(param_combinations)} ---")
        
        # Cria a config para esta rodada
        current_config = {
            'MAX_OUTPUT_LEN': 40, # Valor fixo, pode ser adicionado ao grid se desejar
            'EPOCHS': epochs, # Um número alto, pois o EarlyStopping irá parar antes
            **params # Adiciona os parâmetros da rodada atual
        }
        
        # Roda o treinamento e obtém a pontuação
        validation_score, history = run_training_for_grid_search(
            current_config, X_enc_train, y_dec_train, X_enc_val, y_dec_val
        )
        
        # Salva o resultado
        results.append({
            'score': validation_score,
            'history': history,
            **params
        })

    # --- 4. Exibir os Melhores Resultados ---
    print("\n--- Grid Search Concluído ---")
    
    # Converte os resultados para um DataFrame para fácil visualização
    results_df = pd.DataFrame(results).sort_values(by='score', ascending=True)
    
    print("Melhores combinações de hiperparâmetros (ordenado pela menor perda de validação):")
    print(results_df)

    # Salva os resultados em um CSV
    results_df.to_csv('grid_search_results.csv', index=False)
    print("\nResultados do Grid Search salvos em 'grid_search_results.csv'")

    return history

# %% [markdown]
# ## Submission Utils

# %%
def predict_and_format_submission(config):
    """Carrega os dados de teste, aplica o pipeline e gera a submissão."""
    print("\nIniciando pipeline de inferência...")

    PROCESSED_TEST_PATH_NPZ = 'processed_test_data.npz'
    PROCESSED_TEST_PATH_PKL = 'play_identifiers.pkl'
    
    if not os.path.exists(PROCESSED_TEST_PATH_NPZ) and os.path.exists(PROCESSED_TEST_PATH_PKL):
        # --- Carregar Dados de Teste e Modelos ---
        test_input_df = pd.read_csv(os.path.join(config['BASE_PATH'], 'test_input.csv'))
        # O arquivo 'test.csv' contém os IDs que precisam ser previstos, útil para validação do formato
        test_ids_df = pd.read_csv(os.path.join(config['BASE_PATH'], 'test.csv'))

        encoder_model = tf.keras.models.load_model('encoder_model.h5')
        decoder_model = tf.keras.models.load_model('decoder_model.h5')
        preprocessor = joblib.load('preprocessor.joblib')

        # --- Pré-processamento e Engenharia de Atributos ---
        test_input_df = feature_engineering(test_input_df)
        
        numeric_features = ['x', 'y', 's', 'a', 'player_height_inches', 'player_age', 'dist_to_land_spot', 'delta_x_to_land', 'delta_y_to_land', 'vx', 'vy']
        categorical_features = ['play_direction', 'player_position', 'player_side', 'player_role']
        feature_names = preprocessor.get_feature_names_out()
        
        # Aplicar o pré-processador JÁ AJUSTADO
        processed_test_data = preprocessor.transform(test_input_df[numeric_features + categorical_features])
        processed_test_df = pd.DataFrame(processed_test_data, columns=feature_names, index=test_input_df.index)
        
        id_cols = ['game_id', 'play_id', 'nfl_id', 'num_frames_output']
        final_test_df = pd.concat([test_input_df[id_cols], processed_test_df], axis=1)

        # --- Criar Sequências de Teste ---
        X_enc_test, play_identifiers = create_sequences(final_test_df, None, feature_names, config['MAX_INPUT_LEN'], config['MAX_OUTPUT_LEN'], is_test=True)
        
        print("Salvando dados de teste pré-processados...")
        np.savez_compressed(PROCESSED_TEST_PATH_NPZ, X_enc_test=X_enc_test)
        with open(PROCESSED_TEST_PATH_PKL, 'wb') as f:
            joblib.dump(play_identifiers, f)
    else:
        print("Carregando dados de teste pré-processados do disco...")
        processed_data = np.load(PROCESSED_TEST_PATH_NPZ)
        X_enc_test = processed_data['X_enc_test']
        
        with open(PROCESSED_TEST_PATH_PKL, 'rb') as f:
            play_identifiers = joblib.load(f)

    # --- Gerar Previsões (Loop de Inferência) ---
    predictions = []
    for i in range(len(X_enc_test)):
        input_seq = X_enc_test[i:i+1]
        states_value = encoder_model.predict(input_seq, verbose=0)
        
        target_seq = np.zeros((1, 1, 2)) # Começa com (0,0)
        
        num_frames_to_predict = play_identifiers[i][3]
        output_sequence = []

        for _ in range(num_frames_to_predict):
            output_tokens, h, c = decoder_model.predict([target_seq] + states_value, verbose=0)
            output_sequence.append(output_tokens[0, 0, :])
            target_seq = output_tokens
            states_value = [h, c]
        
        predictions.append(output_sequence)
        
    # --- Formatar para Submissão ---
    submission_rows = []
    for i, play_info in enumerate(play_identifiers):
        game_id, play_id, nfl_id, num_frames = play_info
        predicted_trajectory = predictions[i]
        for frame_idx, coords in enumerate(predicted_trajectory):
            frame_id = frame_idx + 1
            row_id = f"{game_id}_{play_id}_{nfl_id}_{frame_id}"
            submission_rows.append({'id': row_id, 'x': coords[0], 'y': coords[1]})

    submission_df = pd.DataFrame(submission_rows)
    submission_df.to_csv('submission.csv', index=False)
    
    print(f"Arquivo 'submission.csv' gerado com {len(submission_df)} linhas.")

# %% [markdown]
# ## Plot Utils

# %%
def plot_training_history(history):
    """
    Plota os gráficos de perda e RMSE do treinamento e validação.
    
    Args:
        history: O objeto history retornado pelo model.fit() do Keras.
    """
    # Dados de Perda (Loss - Mean Squared Error)
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    
    # Dados da Métrica (Root Mean Squared Error)
    rmse = history.history['root_mean_squared_error']
    val_rmse = history.history['val_root_mean_squared_error']
    
    epochs = range(1, len(loss) + 1)
    
    # Criar a figura com dois subplots (um para Loss, um para RMSE)
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
    
    # Plotar o gráfico de Perda (Loss)
    ax1.plot(epochs, loss, 'bo-', label='Perda de Treinamento')
    ax1.plot(epochs, val_loss, 'ro-', label='Perda de Validação')
    ax1.set_title('Perda (MSE) de Treinamento e Validação')
    ax1.set_xlabel('Épocas')
    ax1.set_ylabel('Perda (MSE)')
    ax1.legend()
    ax1.grid(True)
    
    # Plotar o gráfico da Métrica (RMSE)
    ax2.plot(epochs, rmse, 'bo-', label='RMSE de Treinamento')
    ax2.plot(epochs, val_rmse, 'ro-', label='RMSE de Validação')
    ax2.set_title('Métrica (RMSE) de Treinamento e Validação')
    ax2.set_xlabel('Épocas')
    ax2.set_ylabel('RMSE')
    ax2.legend()
    ax2.grid(True)
    
    plt.tight_layout()
    plt.savefig('training_history.png') # Salva a imagem em um arquivo
    print("Gráfico do histórico de treinamento salvo como 'training_history.png'")

# %% [markdown]
# # Train Data

# %%
config = {
    'BASE_PATH': './nfl-big-data-bowl-2026-prediction/train/',
    'TRAIN_WEEKS': range(1, 16),
    'VALIDATION_WEEKS': range(16, 19),
    'MAX_INPUT_LEN': 30,
    'MAX_OUTPUT_LEN': 40,
    'LATENT_DIM': 256,
    'BATCH_SIZE': 128,
    'EPOCHS': 100, # Aumente para um treinamento real (ex: 50-100)
    'EARLY_STOPPING': 15
}

model, history = run_training_pipeline(config)
# Out:
# Carregando dados pré-processados de 'processed_training_data.npz'...
# Dados carregados com sucesso.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1759426256.657222    9474 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2608 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ encoder_input       │ (None, 30, 35)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_input_for_… │ (None, None, 2)   │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_gru (GRU)   │ [(None, 256),     │    225,024 │ encoder_input[0]… │
# │                     │ (None, 256)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_gru (GRU)   │ [(None, 1, 256),  │    199,680 │ decoder_input_fo… │
# │                     │ (None, 256)]      │            │ encoder_gru[0][1] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_distributed_d… │ (None, 1, 2)      │        514 │ decoder_gru[0][0] │
# │ (TimeDistributed)   │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 425,218 (1.62 MB)
#  Trainable params: 425,218 (1.62 MB)
#  Non-trainable params: 0 (0.00 B)
# Iniciando o treinamento...
# Epoch 1/100
# 2025-10-02 14:31:00.306206: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91301
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 30.7737 - root_mean_squared_error: 5.5474 - val_loss: 15.6360 - val_root_mean_squared_error: 3.9542 - learning_rate: 0.0010
# Epoch 2/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 25s 22ms/step - loss: 14.1103 - root_mean_squared_error: 3.7564 - val_loss: 13.3656 - val_root_mean_squared_error: 3.6559 - learning_rate: 0.0010
# Epoch 3/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 25s 22ms/step - loss: 13.1694 - root_mean_squared_error: 3.6290 - val_loss: 13.1275 - val_root_mean_squared_error: 3.6232 - learning_rate: 0.0010
# Epoch 4/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 25s 22ms/step - loss: 12.7831 - root_mean_squared_error: 3.5753 - val_loss: 12.4603 - val_root_mean_squared_error: 3.5299 - learning_rate: 0.0010
# Epoch 5/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 25s 22ms/step - loss: 12.4847 - root_mean_squared_error: 3.5334 - val_loss: 12.6198 - val_root_mean_squared_error: 3.5524 - learning_rate: 0.0010
# Epoch 6/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 25s 22ms/step - loss: 12.3049 - root_mean_squared_error: 3.5078 - val_loss: 12.6764 - val_root_mean_squared_error: 3.5604 - learning_rate: 0.0010
# Epoch 7/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 25s 22ms/step - loss: 12.2199 - root_mean_squared_error: 3.4957 - val_loss: 12.7436 - val_root_mean_squared_error: 3.5698 - learning_rate: 0.0010
# Epoch 8/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 25s 22ms/step - loss: 12.1152 - root_mean_squared_error: 3.4807 - val_loss: 12.7338 - val_root_mean_squared_error: 3.5684 - learning_rate: 0.0010
# Epoch 9/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 25s 22ms/step - loss: 12.0194 - root_mean_squared_error: 3.4669 - val_loss: 12.3842 - val_root_mean_squared_error: 3.5191 - learning_rate: 0.0010
# Epoch 10/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 25s 22ms/step - loss: 12.0151 - root_mean_squared_error: 3.4663 - val_loss: 12.0544 - val_root_mean_squared_error: 3.4719 - learning_rate: 0.0010
# Epoch 11/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 25s 22ms/step - loss: 11.8109 - root_mean_squared_error: 3.4367 - val_loss: 12.2954 - val_root_mean_squared_error: 3.5065 - learning_rate: 0.0010
# Epoch 12/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 25s 22ms/step - loss: 11.7438 - root_mean_squared_error: 3.4269 - val_loss: 12.8088 - val_root_mean_squared_error: 3.5789 - learning_rate: 0.0010
# Epoch 13/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 25s 22ms/step - loss: 11.6551 - root_mean_squared_error: 3.4139 - val_loss: 12.9683 - val_root_mean_squared_error: 3.6012 - learning_rate: 0.0010
# Epoch 14/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 25s 22ms/step - loss: 11.5856 - root_mean_squared_error: 3.4038 - val_loss: 12.0892 - val_root_mean_squared_error: 3.4769 - learning_rate: 0.0010
# Epoch 15/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 25s 22ms/step - loss: 11.4628 - root_mean_squared_error: 3.3857 - val_loss: 12.6092 - val_root_mean_squared_error: 3.5509 - learning_rate: 0.0010
# Epoch 16/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 25s 22ms/step - loss: 10.7226 - root_mean_squared_error: 3.2745 - val_loss: 12.0524 - val_root_mean_squared_error: 3.4717 - learning_rate: 2.0000e-04
# Epoch 17/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 25s 22ms/step - loss: 10.4997 - root_mean_squared_error: 3.2403 - val_loss: 12.2254 - val_root_mean_squared_error: 3.4965 - learning_rate: 2.0000e-04
# Epoch 18/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 25s 22ms/step - loss: 10.3665 - root_mean_squared_error: 3.2197 - val_loss: 12.0871 - val_root_mean_squared_error: 3.4766 - learning_rate: 2.0000e-04
# Epoch 19/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 25s 22ms/step - loss: 10.2574 - root_mean_squared_error: 3.2027 - val_loss: 12.1895 - val_root_mean_squared_error: 3.4913 - learning_rate: 2.0000e-04
# Epoch 20/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 25s 22ms/step - loss: 10.1437 - root_mean_squared_error: 3.1849 - val_loss: 12.2918 - val_root_mean_squared_error: 3.5060 - learning_rate: 2.0000e-04
# Epoch 21/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 25s 22ms/step - loss: 10.0487 - root_mean_squared_error: 3.1700 - val_loss: 12.2827 - val_root_mean_squared_error: 3.5047 - learning_rate: 2.0000e-04
# Epoch 22/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 25s 22ms/step - loss: 9.7268 - root_mean_squared_error: 3.1188 - val_loss: 12.4529 - val_root_mean_squared_error: 3.5289 - learning_rate: 4.0000e-05
# Epoch 23/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 25s 22ms/step - loss: 9.6303 - root_mean_squared_error: 3.1033 - val_loss: 12.3897 - val_root_mean_squared_error: 3.5199 - learning_rate: 4.0000e-05
# Epoch 24/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 25s 22ms/step - loss: 9.5773 - root_mean_squared_error: 3.0947 - val_loss: 12.5329 - val_root_mean_squared_error: 3.5402 - learning_rate: 4.0000e-05
# Epoch 25/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 25s 22ms/step - loss: 9.5258 - root_mean_squared_error: 3.0864 - val_loss: 12.4940 - val_root_mean_squared_error: 3.5347 - learning_rate: 4.0000e-05
# Epoch 26/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 25s 22ms/step - loss: 9.4848 - root_mean_squared_error: 3.0797 - val_loss: 12.5738 - val_root_mean_squared_error: 3.5459 - learning_rate: 4.0000e-05
# Epoch 27/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 25s 22ms/step - loss: 9.3844 - root_mean_squared_error: 3.0634 - val_loss: 12.6065 - val_root_mean_squared_error: 3.5506 - learning_rate: 8.0000e-06
# Epoch 28/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 25s 22ms/step - loss: 9.3671 - root_mean_squared_error: 3.0606 - val_loss: 12.5852 - val_root_mean_squared_error: 3.5476 - learning_rate: 8.0000e-06
# Epoch 29/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 25s 22ms/step - loss: 9.3566 - root_mean_squared_error: 3.0589 - val_loss: 12.6070 - val_root_mean_squared_error: 3.5506 - learning_rate: 8.0000e-06
# Epoch 30/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 25s 22ms/step - loss: 9.3439 - root_mean_squared_error: 3.0568 - val_loss: 12.6132 - val_root_mean_squared_error: 3.5515 - learning_rate: 8.0000e-06
# Epoch 31/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 25s 22ms/step - loss: 9.3322 - root_mean_squared_error: 3.0549 - val_loss: 12.6667 - val_root_mean_squared_error: 3.5590 - learning_rate: 8.0000e-06
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Treinamento concluído e modelos salvos.

# %%
plot_training_history(history)
# Out:
# Gráfico do histórico de treinamento salvo como 'training_history.png'

# %% [markdown]
# # Train Data - Grid Search

# %%
param_grid = {
    'LATENT_DIM': [128, 256, 512],
    'BATCH_SIZE': [64, 128],
    'LEARNING_RATE': [0.001, 0.0005],
    'DROPOUT_RATE': [0.2, 0.4, 0.6]
}

# %%
history = run_grid_search(param_grid, epochs=100)
# Out:
# Carregando dados pré-processados de 'processed_training_data.npz'...
# Dados carregados com sucesso.
#
# Iniciando Grid Search com 36 combinações.
#
# --- Rodada 1/36 ---
#
# --- Treinando com config: {'MAX_OUTPUT_LEN': 40, 'EPOCHS': 100, 'LATENT_DIM': 128, 'BATCH_SIZE': 64, 'LEARNING_RATE': 0.001, 'DROPOUT_RATE': 0.2} ---
# Epoch 1/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 27s 11ms/step - loss: 32.0410 - root_mean_squared_error: 5.6605 - val_loss: 14.0861 - val_root_mean_squared_error: 3.7531
# Epoch 2/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 13.8754 - root_mean_squared_error: 3.7250 - val_loss: 12.7817 - val_root_mean_squared_error: 3.5752
# Epoch 3/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 13.2432 - root_mean_squared_error: 3.6391 - val_loss: 12.2131 - val_root_mean_squared_error: 3.4947
# Epoch 4/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 12.9950 - root_mean_squared_error: 3.6049 - val_loss: 12.1542 - val_root_mean_squared_error: 3.4863
# Epoch 5/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 25s 11ms/step - loss: 12.7697 - root_mean_squared_error: 3.5735 - val_loss: 12.6596 - val_root_mean_squared_error: 3.5580
# Epoch 6/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 12.6103 - root_mean_squared_error: 3.5511 - val_loss: 12.5334 - val_root_mean_squared_error: 3.5403
# Epoch 7/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 12.5030 - root_mean_squared_error: 3.5360 - val_loss: 12.0706 - val_root_mean_squared_error: 3.4743
# Epoch 8/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 12.3605 - root_mean_squared_error: 3.5157 - val_loss: 12.0288 - val_root_mean_squared_error: 3.4683
# Epoch 9/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 12.2895 - root_mean_squared_error: 3.5056 - val_loss: 12.0045 - val_root_mean_squared_error: 3.4647
# Epoch 10/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - loss: 12.1791 - root_mean_squared_error: 3.4899 - val_loss: 11.8320 - val_root_mean_squared_error: 3.4398
# Epoch 11/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - loss: 12.0604 - root_mean_squared_error: 3.4728 - val_loss: 11.9087 - val_root_mean_squared_error: 3.4509
# Epoch 12/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - loss: 11.9881 - root_mean_squared_error: 3.4624 - val_loss: 11.9322 - val_root_mean_squared_error: 3.4543
# Epoch 13/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - loss: 11.8491 - root_mean_squared_error: 3.4423 - val_loss: 11.9897 - val_root_mean_squared_error: 3.4626
# Epoch 14/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - loss: 11.7748 - root_mean_squared_error: 3.4314 - val_loss: 12.0117 - val_root_mean_squared_error: 3.4658
# Epoch 15/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - loss: 11.6621 - root_mean_squared_error: 3.4150 - val_loss: 11.8737 - val_root_mean_squared_error: 3.4458
# Epoch 16/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - loss: 11.5534 - root_mean_squared_error: 3.3990 - val_loss: 12.0596 - val_root_mean_squared_error: 3.4727
# Epoch 17/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 11.4675 - root_mean_squared_error: 3.3864 - val_loss: 11.9484 - val_root_mean_squared_error: 3.4566
# Epoch 18/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 11.3576 - root_mean_squared_error: 3.3701 - val_loss: 12.1501 - val_root_mean_squared_error: 3.4857
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 10.
#
# --- Rodada 2/36 ---
#
# --- Treinando com config: {'MAX_OUTPUT_LEN': 40, 'EPOCHS': 100, 'LATENT_DIM': 128, 'BATCH_SIZE': 64, 'LEARNING_RATE': 0.001, 'DROPOUT_RATE': 0.4} ---
# Epoch 1/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 26s 11ms/step - loss: 32.7537 - root_mean_squared_error: 5.7231 - val_loss: 13.6444 - val_root_mean_squared_error: 3.6938
# Epoch 2/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 14.9201 - root_mean_squared_error: 3.8626 - val_loss: 12.6842 - val_root_mean_squared_error: 3.5615
# Epoch 3/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - loss: 14.2162 - root_mean_squared_error: 3.7704 - val_loss: 12.3996 - val_root_mean_squared_error: 3.5213
# Epoch 4/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - loss: 13.9188 - root_mean_squared_error: 3.7308 - val_loss: 12.2177 - val_root_mean_squared_error: 3.4954
# Epoch 5/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 13.6887 - root_mean_squared_error: 3.6998 - val_loss: 11.8669 - val_root_mean_squared_error: 3.4448
# Epoch 6/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 13.4910 - root_mean_squared_error: 3.6730 - val_loss: 11.9657 - val_root_mean_squared_error: 3.4591
# Epoch 7/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 25s 11ms/step - loss: 13.3956 - root_mean_squared_error: 3.6600 - val_loss: 12.0480 - val_root_mean_squared_error: 3.4710
# Epoch 8/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 13.2726 - root_mean_squared_error: 3.6432 - val_loss: 11.8788 - val_root_mean_squared_error: 3.4466
# Epoch 9/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - loss: 13.1353 - root_mean_squared_error: 3.6243 - val_loss: 12.1712 - val_root_mean_squared_error: 3.4887
# Epoch 10/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - loss: 13.0656 - root_mean_squared_error: 3.6146 - val_loss: 11.8778 - val_root_mean_squared_error: 3.4464
# Epoch 11/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - loss: 12.9599 - root_mean_squared_error: 3.6000 - val_loss: 11.6910 - val_root_mean_squared_error: 3.4192
# Epoch 12/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - loss: 12.8310 - root_mean_squared_error: 3.5820 - val_loss: 12.3703 - val_root_mean_squared_error: 3.5171
# Epoch 13/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 12.7855 - root_mean_squared_error: 3.5757 - val_loss: 11.9284 - val_root_mean_squared_error: 3.4537
# Epoch 14/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 12.6780 - root_mean_squared_error: 3.5606 - val_loss: 11.9826 - val_root_mean_squared_error: 3.4616
# Epoch 15/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 12.5570 - root_mean_squared_error: 3.5436 - val_loss: 11.9894 - val_root_mean_squared_error: 3.4626
# Epoch 16/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - loss: 12.4803 - root_mean_squared_error: 3.5327 - val_loss: 12.0489 - val_root_mean_squared_error: 3.4712
# Epoch 17/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - loss: 12.3792 - root_mean_squared_error: 3.5184 - val_loss: 12.1118 - val_root_mean_squared_error: 3.4802
# Epoch 18/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - loss: 12.2807 - root_mean_squared_error: 3.5044 - val_loss: 12.1389 - val_root_mean_squared_error: 3.4841
# Epoch 19/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - loss: 12.1506 - root_mean_squared_error: 3.4858 - val_loss: 12.1527 - val_root_mean_squared_error: 3.4861
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 11.
#
# --- Rodada 3/36 ---
#
# --- Treinando com config: {'MAX_OUTPUT_LEN': 40, 'EPOCHS': 100, 'LATENT_DIM': 128, 'BATCH_SIZE': 64, 'LEARNING_RATE': 0.001, 'DROPOUT_RATE': 0.6} ---
# Epoch 1/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 25s 11ms/step - loss: 35.5016 - root_mean_squared_error: 5.9583 - val_loss: 14.3637 - val_root_mean_squared_error: 3.7900
# Epoch 2/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - loss: 17.0759 - root_mean_squared_error: 4.1323 - val_loss: 13.6264 - val_root_mean_squared_error: 3.6914
# Epoch 3/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 16.1954 - root_mean_squared_error: 4.0243 - val_loss: 12.3534 - val_root_mean_squared_error: 3.5147
# Epoch 4/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 15.8219 - root_mean_squared_error: 3.9777 - val_loss: 12.3359 - val_root_mean_squared_error: 3.5122
# Epoch 5/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 15.5787 - root_mean_squared_error: 3.9470 - val_loss: 12.1795 - val_root_mean_squared_error: 3.4899
# Epoch 6/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - loss: 15.4544 - root_mean_squared_error: 3.9312 - val_loss: 12.1209 - val_root_mean_squared_error: 3.4815
# Epoch 7/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - loss: 15.3148 - root_mean_squared_error: 3.9134 - val_loss: 12.2867 - val_root_mean_squared_error: 3.5052
# Epoch 8/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 15.1736 - root_mean_squared_error: 3.8953 - val_loss: 12.0140 - val_root_mean_squared_error: 3.4661
# Epoch 9/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 15.0771 - root_mean_squared_error: 3.8829 - val_loss: 12.5541 - val_root_mean_squared_error: 3.5432
# Epoch 10/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - loss: 14.9935 - root_mean_squared_error: 3.8721 - val_loss: 12.5123 - val_root_mean_squared_error: 3.5373
# Epoch 11/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - loss: 14.9018 - root_mean_squared_error: 3.8603 - val_loss: 11.9241 - val_root_mean_squared_error: 3.4531
# Epoch 12/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - loss: 14.7661 - root_mean_squared_error: 3.8427 - val_loss: 12.1294 - val_root_mean_squared_error: 3.4827
# Epoch 13/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - loss: 14.6690 - root_mean_squared_error: 3.8300 - val_loss: 12.1527 - val_root_mean_squared_error: 3.4861
# Epoch 14/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - loss: 14.5847 - root_mean_squared_error: 3.8190 - val_loss: 12.1036 - val_root_mean_squared_error: 3.4790
# Epoch 15/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - loss: 14.5067 - root_mean_squared_error: 3.8088 - val_loss: 12.4590 - val_root_mean_squared_error: 3.5297
# Epoch 16/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - loss: 14.4263 - root_mean_squared_error: 3.7982 - val_loss: 12.0923 - val_root_mean_squared_error: 3.4774
# Epoch 17/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 14.3121 - root_mean_squared_error: 3.7831 - val_loss: 11.9994 - val_root_mean_squared_error: 3.4640
# Epoch 18/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 14.2257 - root_mean_squared_error: 3.7717 - val_loss: 12.1269 - val_root_mean_squared_error: 3.4824
# Epoch 19/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - loss: 14.1499 - root_mean_squared_error: 3.7616 - val_loss: 12.3095 - val_root_mean_squared_error: 3.5085
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 11.
#
# --- Rodada 4/36 ---
#
# --- Treinando com config: {'MAX_OUTPUT_LEN': 40, 'EPOCHS': 100, 'LATENT_DIM': 128, 'BATCH_SIZE': 64, 'LEARNING_RATE': 0.0005, 'DROPOUT_RATE': 0.2} ---
# Epoch 1/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 25s 11ms/step - loss: 46.1466 - root_mean_squared_error: 6.7931 - val_loss: 17.2900 - val_root_mean_squared_error: 4.1581
# Epoch 2/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - loss: 15.1642 - root_mean_squared_error: 3.8941 - val_loss: 13.0644 - val_root_mean_squared_error: 3.6145
# Epoch 3/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - loss: 13.5156 - root_mean_squared_error: 3.6764 - val_loss: 12.7979 - val_root_mean_squared_error: 3.5774
# Epoch 4/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - loss: 13.0945 - root_mean_squared_error: 3.6186 - val_loss: 12.3337 - val_root_mean_squared_error: 3.5119
# Epoch 5/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 12.8623 - root_mean_squared_error: 3.5864 - val_loss: 12.4158 - val_root_mean_squared_error: 3.5236
# Epoch 6/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 12.6945 - root_mean_squared_error: 3.5629 - val_loss: 12.0968 - val_root_mean_squared_error: 3.4780
# Epoch 7/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 12.5609 - root_mean_squared_error: 3.5441 - val_loss: 12.0101 - val_root_mean_squared_error: 3.4656
# Epoch 8/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 12.4517 - root_mean_squared_error: 3.5287 - val_loss: 12.0725 - val_root_mean_squared_error: 3.4746
# Epoch 9/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 12.3574 - root_mean_squared_error: 3.5153 - val_loss: 11.9599 - val_root_mean_squared_error: 3.4583
# Epoch 10/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 12.2738 - root_mean_squared_error: 3.5034 - val_loss: 11.9913 - val_root_mean_squared_error: 3.4628
# Epoch 11/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 12.1779 - root_mean_squared_error: 3.4897 - val_loss: 12.1470 - val_root_mean_squared_error: 3.4853
# Epoch 12/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 12.0937 - root_mean_squared_error: 3.4776 - val_loss: 12.0531 - val_root_mean_squared_error: 3.4718
# Epoch 13/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 12.0105 - root_mean_squared_error: 3.4656 - val_loss: 11.8151 - val_root_mean_squared_error: 3.4373
# Epoch 14/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 11.9304 - root_mean_squared_error: 3.4540 - val_loss: 11.9999 - val_root_mean_squared_error: 3.4641
# Epoch 15/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 11.8369 - root_mean_squared_error: 3.4405 - val_loss: 12.0548 - val_root_mean_squared_error: 3.4720
# Epoch 16/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 11.7505 - root_mean_squared_error: 3.4279 - val_loss: 11.8933 - val_root_mean_squared_error: 3.4487
# Epoch 17/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 11.6780 - root_mean_squared_error: 3.4173 - val_loss: 11.8987 - val_root_mean_squared_error: 3.4494
# Epoch 18/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 11.5945 - root_mean_squared_error: 3.4051 - val_loss: 11.8637 - val_root_mean_squared_error: 3.4444
# Epoch 19/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 11.4895 - root_mean_squared_error: 3.3896 - val_loss: 11.9326 - val_root_mean_squared_error: 3.4544
# Epoch 20/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 11.4329 - root_mean_squared_error: 3.3813 - val_loss: 12.1019 - val_root_mean_squared_error: 3.4788
# Epoch 21/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 11.3222 - root_mean_squared_error: 3.3649 - val_loss: 12.5263 - val_root_mean_squared_error: 3.5393
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 13.
#
# --- Rodada 5/36 ---
#
# --- Treinando com config: {'MAX_OUTPUT_LEN': 40, 'EPOCHS': 100, 'LATENT_DIM': 128, 'BATCH_SIZE': 64, 'LEARNING_RATE': 0.0005, 'DROPOUT_RATE': 0.4} ---
# Epoch 1/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 26s 11ms/step - loss: 49.1877 - root_mean_squared_error: 7.0134 - val_loss: 16.8745 - val_root_mean_squared_error: 4.1079
# Epoch 2/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 16.3348 - root_mean_squared_error: 4.0416 - val_loss: 13.2581 - val_root_mean_squared_error: 3.6412
# Epoch 3/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 14.6136 - root_mean_squared_error: 3.8228 - val_loss: 12.6821 - val_root_mean_squared_error: 3.5612
# Epoch 4/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 14.1490 - root_mean_squared_error: 3.7615 - val_loss: 12.3199 - val_root_mean_squared_error: 3.5100
# Epoch 5/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 13.9049 - root_mean_squared_error: 3.7289 - val_loss: 12.1857 - val_root_mean_squared_error: 3.4908
# Epoch 6/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 13.7372 - root_mean_squared_error: 3.7064 - val_loss: 12.0878 - val_root_mean_squared_error: 3.4767
# Epoch 7/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 13.5808 - root_mean_squared_error: 3.6852 - val_loss: 12.0578 - val_root_mean_squared_error: 3.4724
# Epoch 8/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 13.4469 - root_mean_squared_error: 3.6670 - val_loss: 11.8415 - val_root_mean_squared_error: 3.4411
# Epoch 9/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 13.3217 - root_mean_squared_error: 3.6499 - val_loss: 12.2776 - val_root_mean_squared_error: 3.5039
# Epoch 10/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 13.2224 - root_mean_squared_error: 3.6363 - val_loss: 11.9368 - val_root_mean_squared_error: 3.4550
# Epoch 11/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 13.1519 - root_mean_squared_error: 3.6266 - val_loss: 11.8741 - val_root_mean_squared_error: 3.4459
# Epoch 12/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 13.0424 - root_mean_squared_error: 3.6114 - val_loss: 11.8813 - val_root_mean_squared_error: 3.4469
# Epoch 13/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 12.9560 - root_mean_squared_error: 3.5994 - val_loss: 11.7810 - val_root_mean_squared_error: 3.4323
# Epoch 14/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 12.8878 - root_mean_squared_error: 3.5900 - val_loss: 12.0914 - val_root_mean_squared_error: 3.4773
# Epoch 15/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 12.8180 - root_mean_squared_error: 3.5802 - val_loss: 11.8659 - val_root_mean_squared_error: 3.4447
# Epoch 16/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 12.7345 - root_mean_squared_error: 3.5685 - val_loss: 12.0272 - val_root_mean_squared_error: 3.4680
# Epoch 17/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 12.6580 - root_mean_squared_error: 3.5578 - val_loss: 12.1783 - val_root_mean_squared_error: 3.4897
# Epoch 18/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 12.5337 - root_mean_squared_error: 3.5403 - val_loss: 12.0439 - val_root_mean_squared_error: 3.4704
# Epoch 19/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 12.5214 - root_mean_squared_error: 3.5386 - val_loss: 12.2126 - val_root_mean_squared_error: 3.4946
# Epoch 20/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 12.4017 - root_mean_squared_error: 3.5216 - val_loss: 12.2888 - val_root_mean_squared_error: 3.5055
# Epoch 21/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 12.3307 - root_mean_squared_error: 3.5115 - val_loss: 12.1576 - val_root_mean_squared_error: 3.4868
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 13.
#
# --- Rodada 6/36 ---
#
# --- Treinando com config: {'MAX_OUTPUT_LEN': 40, 'EPOCHS': 100, 'LATENT_DIM': 128, 'BATCH_SIZE': 64, 'LEARNING_RATE': 0.0005, 'DROPOUT_RATE': 0.6} ---
# Epoch 1/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 26s 11ms/step - loss: 51.6320 - root_mean_squared_error: 7.1855 - val_loss: 17.9540 - val_root_mean_squared_error: 4.2372
# Epoch 2/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 18.6314 - root_mean_squared_error: 4.3164 - val_loss: 13.6312 - val_root_mean_squared_error: 3.6920
# Epoch 3/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 16.6417 - root_mean_squared_error: 4.0794 - val_loss: 12.6638 - val_root_mean_squared_error: 3.5586
# Epoch 4/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 16.1044 - root_mean_squared_error: 4.0130 - val_loss: 12.4495 - val_root_mean_squared_error: 3.5284
# Epoch 5/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 15.8249 - root_mean_squared_error: 3.9781 - val_loss: 12.3902 - val_root_mean_squared_error: 3.5200
# Epoch 6/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 15.6195 - root_mean_squared_error: 3.9521 - val_loss: 12.3867 - val_root_mean_squared_error: 3.5195
# Epoch 7/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 15.4314 - root_mean_squared_error: 3.9283 - val_loss: 12.5292 - val_root_mean_squared_error: 3.5397
# Epoch 8/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 15.3170 - root_mean_squared_error: 3.9137 - val_loss: 12.2097 - val_root_mean_squared_error: 3.4942
# Epoch 9/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 15.1711 - root_mean_squared_error: 3.8950 - val_loss: 12.0055 - val_root_mean_squared_error: 3.4649
# Epoch 10/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 15.0772 - root_mean_squared_error: 3.8829 - val_loss: 12.0312 - val_root_mean_squared_error: 3.4686
# Epoch 11/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 14.9803 - root_mean_squared_error: 3.8704 - val_loss: 12.3867 - val_root_mean_squared_error: 3.5195
# Epoch 12/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 14.9191 - root_mean_squared_error: 3.8625 - val_loss: 12.3112 - val_root_mean_squared_error: 3.5087
# Epoch 13/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 14.8010 - root_mean_squared_error: 3.8472 - val_loss: 12.3644 - val_root_mean_squared_error: 3.5163
# Epoch 14/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 14.7561 - root_mean_squared_error: 3.8414 - val_loss: 12.3328 - val_root_mean_squared_error: 3.5118
# Epoch 15/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 14.6327 - root_mean_squared_error: 3.8253 - val_loss: 11.9685 - val_root_mean_squared_error: 3.4596
# Epoch 16/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 14.5459 - root_mean_squared_error: 3.8139 - val_loss: 12.0264 - val_root_mean_squared_error: 3.4679
# Epoch 17/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 14.5028 - root_mean_squared_error: 3.8082 - val_loss: 11.9548 - val_root_mean_squared_error: 3.4576
# Epoch 18/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 14.3801 - root_mean_squared_error: 3.7921 - val_loss: 11.9653 - val_root_mean_squared_error: 3.4591
# Epoch 19/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 14.3616 - root_mean_squared_error: 3.7897 - val_loss: 11.9919 - val_root_mean_squared_error: 3.4629
# Epoch 20/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 14.2803 - root_mean_squared_error: 3.7789 - val_loss: 12.5850 - val_root_mean_squared_error: 3.5475
# Epoch 21/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 14.1628 - root_mean_squared_error: 3.7633 - val_loss: 12.5129 - val_root_mean_squared_error: 3.5374
# Epoch 22/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 14.0710 - root_mean_squared_error: 3.7511 - val_loss: 12.6420 - val_root_mean_squared_error: 3.5556
# Epoch 23/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 14.0445 - root_mean_squared_error: 3.7476 - val_loss: 12.4830 - val_root_mean_squared_error: 3.5331
# Epoch 24/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 13.9365 - root_mean_squared_error: 3.7332 - val_loss: 12.5116 - val_root_mean_squared_error: 3.5372
# Epoch 25/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 13.8733 - root_mean_squared_error: 3.7247 - val_loss: 12.1167 - val_root_mean_squared_error: 3.4809
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 17.
#
# --- Rodada 7/36 ---
#
# --- Treinando com config: {'MAX_OUTPUT_LEN': 40, 'EPOCHS': 100, 'LATENT_DIM': 128, 'BATCH_SIZE': 128, 'LEARNING_RATE': 0.001, 'DROPOUT_RATE': 0.2} ---
# Epoch 1/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 19s 16ms/step - loss: 48.1715 - root_mean_squared_error: 6.9406 - val_loss: 17.1209 - val_root_mean_squared_error: 4.1377
# Epoch 2/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 15.2829 - root_mean_squared_error: 3.9093 - val_loss: 13.3354 - val_root_mean_squared_error: 3.6518
# Epoch 3/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 13.5686 - root_mean_squared_error: 3.6836 - val_loss: 12.3875 - val_root_mean_squared_error: 3.5196
# Epoch 4/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 13.0917 - root_mean_squared_error: 3.6182 - val_loss: 12.2194 - val_root_mean_squared_error: 3.4956
# Epoch 5/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 12.8775 - root_mean_squared_error: 3.5885 - val_loss: 12.1322 - val_root_mean_squared_error: 3.4831
# Epoch 6/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 12.6898 - root_mean_squared_error: 3.5623 - val_loss: 12.2029 - val_root_mean_squared_error: 3.4933
# Epoch 7/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 12.5539 - root_mean_squared_error: 3.5431 - val_loss: 12.2117 - val_root_mean_squared_error: 3.4945
# Epoch 8/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - loss: 12.4510 - root_mean_squared_error: 3.5286 - val_loss: 11.8053 - val_root_mean_squared_error: 3.4359
# Epoch 9/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 12.3431 - root_mean_squared_error: 3.5133 - val_loss: 11.8984 - val_root_mean_squared_error: 3.4494
# Epoch 10/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - loss: 12.2277 - root_mean_squared_error: 3.4968 - val_loss: 11.9157 - val_root_mean_squared_error: 3.4519
# Epoch 11/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 12.1586 - root_mean_squared_error: 3.4869 - val_loss: 11.7776 - val_root_mean_squared_error: 3.4319
# Epoch 12/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - loss: 12.0510 - root_mean_squared_error: 3.4715 - val_loss: 11.8539 - val_root_mean_squared_error: 3.4429
# Epoch 13/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 11.9773 - root_mean_squared_error: 3.4608 - val_loss: 11.9694 - val_root_mean_squared_error: 3.4597
# Epoch 14/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - loss: 11.9064 - root_mean_squared_error: 3.4506 - val_loss: 12.1693 - val_root_mean_squared_error: 3.4885
# Epoch 15/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 11.7923 - root_mean_squared_error: 3.4340 - val_loss: 12.0509 - val_root_mean_squared_error: 3.4714
# Epoch 16/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 11.7257 - root_mean_squared_error: 3.4243 - val_loss: 12.0346 - val_root_mean_squared_error: 3.4691
# Epoch 17/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 11.6030 - root_mean_squared_error: 3.4063 - val_loss: 11.9945 - val_root_mean_squared_error: 3.4633
# Epoch 18/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 11.5550 - root_mean_squared_error: 3.3993 - val_loss: 12.2938 - val_root_mean_squared_error: 3.5062
# Epoch 19/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 11.4312 - root_mean_squared_error: 3.3810 - val_loss: 12.0312 - val_root_mean_squared_error: 3.4686
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 11.
#
# --- Rodada 8/36 ---
#
# --- Treinando com config: {'MAX_OUTPUT_LEN': 40, 'EPOCHS': 100, 'LATENT_DIM': 128, 'BATCH_SIZE': 128, 'LEARNING_RATE': 0.001, 'DROPOUT_RATE': 0.4} ---
# Epoch 1/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 47.3735 - root_mean_squared_error: 6.8828 - val_loss: 17.1797 - val_root_mean_squared_error: 4.1448
# Epoch 2/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 16.4916 - root_mean_squared_error: 4.0610 - val_loss: 13.2018 - val_root_mean_squared_error: 3.6334
# Epoch 3/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 14.6734 - root_mean_squared_error: 3.8306 - val_loss: 12.4976 - val_root_mean_squared_error: 3.5352
# Epoch 4/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 14.1469 - root_mean_squared_error: 3.7612 - val_loss: 12.2895 - val_root_mean_squared_error: 3.5056
# Epoch 5/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 13.8512 - root_mean_squared_error: 3.7217 - val_loss: 12.0139 - val_root_mean_squared_error: 3.4661
# Epoch 6/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 13.6791 - root_mean_squared_error: 3.6985 - val_loss: 12.3561 - val_root_mean_squared_error: 3.5151
# Epoch 7/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 13.5280 - root_mean_squared_error: 3.6780 - val_loss: 12.0576 - val_root_mean_squared_error: 3.4724
# Epoch 8/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 13.3768 - root_mean_squared_error: 3.6574 - val_loss: 11.9421 - val_root_mean_squared_error: 3.4557
# Epoch 9/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 13.2559 - root_mean_squared_error: 3.6409 - val_loss: 12.0235 - val_root_mean_squared_error: 3.4675
# Epoch 10/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 13.1644 - root_mean_squared_error: 3.6283 - val_loss: 12.2523 - val_root_mean_squared_error: 3.5003
# Epoch 11/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 13.0664 - root_mean_squared_error: 3.6148 - val_loss: 12.0722 - val_root_mean_squared_error: 3.4745
# Epoch 12/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 12.9239 - root_mean_squared_error: 3.5950 - val_loss: 11.9155 - val_root_mean_squared_error: 3.4519
# Epoch 13/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 12.8854 - root_mean_squared_error: 3.5896 - val_loss: 12.1113 - val_root_mean_squared_error: 3.4801
# Epoch 14/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 12.7793 - root_mean_squared_error: 3.5748 - val_loss: 11.9809 - val_root_mean_squared_error: 3.4613
# Epoch 15/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 12.7010 - root_mean_squared_error: 3.5638 - val_loss: 12.1124 - val_root_mean_squared_error: 3.4803
# Epoch 16/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 12.6160 - root_mean_squared_error: 3.5519 - val_loss: 12.1815 - val_root_mean_squared_error: 3.4902
# Epoch 17/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 12.4856 - root_mean_squared_error: 3.5335 - val_loss: 12.3147 - val_root_mean_squared_error: 3.5092
# Epoch 18/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 12.3710 - root_mean_squared_error: 3.5172 - val_loss: 12.2142 - val_root_mean_squared_error: 3.4949
# Epoch 19/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 12.2916 - root_mean_squared_error: 3.5059 - val_loss: 12.3349 - val_root_mean_squared_error: 3.5121
# Epoch 20/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 12.2118 - root_mean_squared_error: 3.4945 - val_loss: 12.1786 - val_root_mean_squared_error: 3.4898
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 12.
#
# --- Rodada 9/36 ---
#
# --- Treinando com config: {'MAX_OUTPUT_LEN': 40, 'EPOCHS': 100, 'LATENT_DIM': 128, 'BATCH_SIZE': 128, 'LEARNING_RATE': 0.001, 'DROPOUT_RATE': 0.6} ---
# Epoch 1/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 48.6428 - root_mean_squared_error: 6.9744 - val_loss: 17.6169 - val_root_mean_squared_error: 4.1972
# Epoch 2/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 18.4983 - root_mean_squared_error: 4.3010 - val_loss: 13.5680 - val_root_mean_squared_error: 3.6835
# Epoch 3/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 16.7680 - root_mean_squared_error: 4.0949 - val_loss: 12.8833 - val_root_mean_squared_error: 3.5893
# Epoch 4/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 16.1892 - root_mean_squared_error: 4.0236 - val_loss: 12.8045 - val_root_mean_squared_error: 3.5783
# Epoch 5/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 15.8774 - root_mean_squared_error: 3.9846 - val_loss: 12.4766 - val_root_mean_squared_error: 3.5322
# Epoch 6/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 15.6135 - root_mean_squared_error: 3.9514 - val_loss: 12.3918 - val_root_mean_squared_error: 3.5202
# Epoch 7/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 15.4325 - root_mean_squared_error: 3.9284 - val_loss: 12.5340 - val_root_mean_squared_error: 3.5403
# Epoch 8/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 15.3352 - root_mean_squared_error: 3.9160 - val_loss: 12.2959 - val_root_mean_squared_error: 3.5066
# Epoch 9/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 15.2257 - root_mean_squared_error: 3.9020 - val_loss: 11.8892 - val_root_mean_squared_error: 3.4481
# Epoch 10/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 15.1103 - root_mean_squared_error: 3.8872 - val_loss: 12.1898 - val_root_mean_squared_error: 3.4914
# Epoch 11/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 15.0275 - root_mean_squared_error: 3.8765 - val_loss: 12.0110 - val_root_mean_squared_error: 3.4657
# Epoch 12/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 14.9068 - root_mean_squared_error: 3.8609 - val_loss: 12.1420 - val_root_mean_squared_error: 3.4845
# Epoch 13/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 14.8236 - root_mean_squared_error: 3.8501 - val_loss: 12.2015 - val_root_mean_squared_error: 3.4931
# Epoch 14/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 14.7112 - root_mean_squared_error: 3.8355 - val_loss: 12.2443 - val_root_mean_squared_error: 3.4992
# Epoch 15/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 14.6432 - root_mean_squared_error: 3.8266 - val_loss: 12.6824 - val_root_mean_squared_error: 3.5612
# Epoch 16/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 14.5742 - root_mean_squared_error: 3.8176 - val_loss: 12.1323 - val_root_mean_squared_error: 3.4831
# Epoch 17/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 14.4761 - root_mean_squared_error: 3.8047 - val_loss: 12.1879 - val_root_mean_squared_error: 3.4911
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 9.
#
# --- Rodada 10/36 ---
#
# --- Treinando com config: {'MAX_OUTPUT_LEN': 40, 'EPOCHS': 100, 'LATENT_DIM': 128, 'BATCH_SIZE': 128, 'LEARNING_RATE': 0.0005, 'DROPOUT_RATE': 0.2} ---
# Epoch 1/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 19s 16ms/step - loss: 68.1173 - root_mean_squared_error: 8.2533 - val_loss: 28.0762 - val_root_mean_squared_error: 5.2987
# Epoch 2/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 21.2018 - root_mean_squared_error: 4.6045 - val_loss: 15.9435 - val_root_mean_squared_error: 3.9929
# Epoch 3/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 15.3045 - root_mean_squared_error: 3.9121 - val_loss: 13.2365 - val_root_mean_squared_error: 3.6382
# Epoch 4/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 13.7584 - root_mean_squared_error: 3.7092 - val_loss: 12.5558 - val_root_mean_squared_error: 3.5434
# Epoch 5/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 13.2198 - root_mean_squared_error: 3.6359 - val_loss: 12.6041 - val_root_mean_squared_error: 3.5502
# Epoch 6/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 12.9665 - root_mean_squared_error: 3.6009 - val_loss: 12.3336 - val_root_mean_squared_error: 3.5119
# Epoch 7/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 12.7996 - root_mean_squared_error: 3.5776 - val_loss: 12.1882 - val_root_mean_squared_error: 3.4912
# Epoch 8/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 12.6573 - root_mean_squared_error: 3.5577 - val_loss: 12.1138 - val_root_mean_squared_error: 3.4805
# Epoch 9/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 12.5462 - root_mean_squared_error: 3.5421 - val_loss: 12.0699 - val_root_mean_squared_error: 3.4742
# Epoch 10/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 12.4545 - root_mean_squared_error: 3.5291 - val_loss: 11.9962 - val_root_mean_squared_error: 3.4636
# Epoch 11/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - loss: 12.3743 - root_mean_squared_error: 3.5177 - val_loss: 11.9100 - val_root_mean_squared_error: 3.4511
# Epoch 12/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 12.2480 - root_mean_squared_error: 3.4997 - val_loss: 12.0096 - val_root_mean_squared_error: 3.4655
# Epoch 13/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 12.1762 - root_mean_squared_error: 3.4894 - val_loss: 11.9473 - val_root_mean_squared_error: 3.4565
# Epoch 14/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 12.1036 - root_mean_squared_error: 3.4790 - val_loss: 12.1652 - val_root_mean_squared_error: 3.4879
# Epoch 15/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 12.0280 - root_mean_squared_error: 3.4681 - val_loss: 12.0149 - val_root_mean_squared_error: 3.4663
# Epoch 16/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 11.9710 - root_mean_squared_error: 3.4599 - val_loss: 11.9628 - val_root_mean_squared_error: 3.4587
# Epoch 17/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 11.8942 - root_mean_squared_error: 3.4488 - val_loss: 12.2837 - val_root_mean_squared_error: 3.5048
# Epoch 18/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 11.8398 - root_mean_squared_error: 3.4409 - val_loss: 12.0196 - val_root_mean_squared_error: 3.4669
# Epoch 19/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 11.7945 - root_mean_squared_error: 3.4343 - val_loss: 12.2857 - val_root_mean_squared_error: 3.5051
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 11.
#
# --- Rodada 11/36 ---
#
# --- Treinando com config: {'MAX_OUTPUT_LEN': 40, 'EPOCHS': 100, 'LATENT_DIM': 128, 'BATCH_SIZE': 128, 'LEARNING_RATE': 0.0005, 'DROPOUT_RATE': 0.4} ---
# Epoch 1/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 69.4815 - root_mean_squared_error: 8.3356 - val_loss: 29.5189 - val_root_mean_squared_error: 5.4331
# Epoch 2/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 22.8175 - root_mean_squared_error: 4.7768 - val_loss: 16.0766 - val_root_mean_squared_error: 4.0096
# Epoch 3/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - loss: 16.3899 - root_mean_squared_error: 4.0484 - val_loss: 13.5326 - val_root_mean_squared_error: 3.6787
# Epoch 4/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 14.8716 - root_mean_squared_error: 3.8564 - val_loss: 12.8026 - val_root_mean_squared_error: 3.5781
# Epoch 5/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 18s 16ms/step - loss: 14.2774 - root_mean_squared_error: 3.7785 - val_loss: 13.0093 - val_root_mean_squared_error: 3.6068
# Epoch 6/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 13.9874 - root_mean_squared_error: 3.7400 - val_loss: 12.1205 - val_root_mean_squared_error: 3.4814
# Epoch 7/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 18s 16ms/step - loss: 13.7478 - root_mean_squared_error: 3.7078 - val_loss: 12.1849 - val_root_mean_squared_error: 3.4907
# Epoch 8/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 13.6289 - root_mean_squared_error: 3.6917 - val_loss: 12.0459 - val_root_mean_squared_error: 3.4707
# Epoch 9/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - loss: 13.5426 - root_mean_squared_error: 3.6800 - val_loss: 12.0082 - val_root_mean_squared_error: 3.4653
# Epoch 10/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 13.3769 - root_mean_squared_error: 3.6574 - val_loss: 12.4408 - val_root_mean_squared_error: 3.5272
# Epoch 11/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 13.3046 - root_mean_squared_error: 3.6476 - val_loss: 11.9439 - val_root_mean_squared_error: 3.4560
# Epoch 12/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 13.2430 - root_mean_squared_error: 3.6391 - val_loss: 12.0822 - val_root_mean_squared_error: 3.4759
# Epoch 13/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - loss: 13.1655 - root_mean_squared_error: 3.6284 - val_loss: 12.0577 - val_root_mean_squared_error: 3.4724
# Epoch 14/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 13.0868 - root_mean_squared_error: 3.6176 - val_loss: 12.0241 - val_root_mean_squared_error: 3.4676
# Epoch 15/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - loss: 13.0351 - root_mean_squared_error: 3.6104 - val_loss: 11.8583 - val_root_mean_squared_error: 3.4436
# Epoch 16/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 12.9607 - root_mean_squared_error: 3.6001 - val_loss: 12.1184 - val_root_mean_squared_error: 3.4811
# Epoch 17/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - loss: 12.8889 - root_mean_squared_error: 3.5901 - val_loss: 12.1057 - val_root_mean_squared_error: 3.4793
# Epoch 18/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 12.7774 - root_mean_squared_error: 3.5746 - val_loss: 12.1889 - val_root_mean_squared_error: 3.4913
# Epoch 19/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - loss: 12.7354 - root_mean_squared_error: 3.5687 - val_loss: 11.9857 - val_root_mean_squared_error: 3.4620
# Epoch 20/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 12.6728 - root_mean_squared_error: 3.5599 - val_loss: 11.9315 - val_root_mean_squared_error: 3.4542
# Epoch 21/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 12.5985 - root_mean_squared_error: 3.5494 - val_loss: 11.9701 - val_root_mean_squared_error: 3.4598
# Epoch 22/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 12.5657 - root_mean_squared_error: 3.5448 - val_loss: 12.0959 - val_root_mean_squared_error: 3.4779
# Epoch 23/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 12.4686 - root_mean_squared_error: 3.5311 - val_loss: 12.1419 - val_root_mean_squared_error: 3.4845
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 15.
#
# --- Rodada 12/36 ---
#
# --- Treinando com config: {'MAX_OUTPUT_LEN': 40, 'EPOCHS': 100, 'LATENT_DIM': 128, 'BATCH_SIZE': 128, 'LEARNING_RATE': 0.0005, 'DROPOUT_RATE': 0.6} ---
# Epoch 1/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 70.1224 - root_mean_squared_error: 8.3739 - val_loss: 28.5830 - val_root_mean_squared_error: 5.3463
# Epoch 2/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 23.9186 - root_mean_squared_error: 4.8907 - val_loss: 16.3931 - val_root_mean_squared_error: 4.0488
# Epoch 3/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - loss: 18.1532 - root_mean_squared_error: 4.2607 - val_loss: 13.8211 - val_root_mean_squared_error: 3.7177
# Epoch 4/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 16.7140 - root_mean_squared_error: 4.0883 - val_loss: 13.4321 - val_root_mean_squared_error: 3.6650
# Epoch 5/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - loss: 16.1171 - root_mean_squared_error: 4.0146 - val_loss: 12.5366 - val_root_mean_squared_error: 3.5407
# Epoch 6/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - loss: 15.8371 - root_mean_squared_error: 3.9796 - val_loss: 12.4974 - val_root_mean_squared_error: 3.5352
# Epoch 7/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - loss: 15.6063 - root_mean_squared_error: 3.9505 - val_loss: 12.2542 - val_root_mean_squared_error: 3.5006
# Epoch 8/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 15.4481 - root_mean_squared_error: 3.9304 - val_loss: 12.2723 - val_root_mean_squared_error: 3.5032
# Epoch 9/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - loss: 15.3360 - root_mean_squared_error: 3.9161 - val_loss: 12.4563 - val_root_mean_squared_error: 3.5294
# Epoch 10/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 15.2005 - root_mean_squared_error: 3.8988 - val_loss: 12.2479 - val_root_mean_squared_error: 3.4997
# Epoch 11/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - loss: 15.1248 - root_mean_squared_error: 3.8891 - val_loss: 12.2929 - val_root_mean_squared_error: 3.5061
# Epoch 12/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 15.0299 - root_mean_squared_error: 3.8768 - val_loss: 12.1465 - val_root_mean_squared_error: 3.4852
# Epoch 13/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 14.9471 - root_mean_squared_error: 3.8661 - val_loss: 12.5700 - val_root_mean_squared_error: 3.5454
# Epoch 14/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 14.8572 - root_mean_squared_error: 3.8545 - val_loss: 12.0924 - val_root_mean_squared_error: 3.4774
# Epoch 15/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 14.7816 - root_mean_squared_error: 3.8447 - val_loss: 12.0539 - val_root_mean_squared_error: 3.4719
# Epoch 16/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 14.7071 - root_mean_squared_error: 3.8350 - val_loss: 12.2685 - val_root_mean_squared_error: 3.5026
# Epoch 17/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 14.6345 - root_mean_squared_error: 3.8255 - val_loss: 12.0605 - val_root_mean_squared_error: 3.4728
# Epoch 18/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 14.5766 - root_mean_squared_error: 3.8179 - val_loss: 12.0245 - val_root_mean_squared_error: 3.4676
# Epoch 19/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 14.5416 - root_mean_squared_error: 3.8133 - val_loss: 12.0565 - val_root_mean_squared_error: 3.4722
# Epoch 20/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 14.4518 - root_mean_squared_error: 3.8016 - val_loss: 12.3800 - val_root_mean_squared_error: 3.5185
# Epoch 21/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - loss: 14.3545 - root_mean_squared_error: 3.7887 - val_loss: 12.2914 - val_root_mean_squared_error: 3.5059
# Epoch 22/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 14.2916 - root_mean_squared_error: 3.7804 - val_loss: 12.2041 - val_root_mean_squared_error: 3.4934
# Epoch 23/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - loss: 14.2396 - root_mean_squared_error: 3.7735 - val_loss: 12.2593 - val_root_mean_squared_error: 3.5013
# Epoch 24/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - loss: 14.1782 - root_mean_squared_error: 3.7654 - val_loss: 12.1869 - val_root_mean_squared_error: 3.4910
# Epoch 25/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - loss: 14.0991 - root_mean_squared_error: 3.7549 - val_loss: 12.2522 - val_root_mean_squared_error: 3.5003
# Epoch 26/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 14.0087 - root_mean_squared_error: 3.7428 - val_loss: 12.2225 - val_root_mean_squared_error: 3.4961
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 18.
#
# --- Rodada 13/36 ---
#
# --- Treinando com config: {'MAX_OUTPUT_LEN': 40, 'EPOCHS': 100, 'LATENT_DIM': 256, 'BATCH_SIZE': 64, 'LEARNING_RATE': 0.001, 'DROPOUT_RATE': 0.2} ---
# Epoch 1/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 43s 18ms/step - loss: 23.4877 - root_mean_squared_error: 4.8464 - val_loss: 13.1332 - val_root_mean_squared_error: 3.6240
# Epoch 2/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 41s 18ms/step - loss: 13.4554 - root_mean_squared_error: 3.6682 - val_loss: 12.6065 - val_root_mean_squared_error: 3.5506
# Epoch 3/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 41s 18ms/step - loss: 12.9169 - root_mean_squared_error: 3.5940 - val_loss: 12.1621 - val_root_mean_squared_error: 3.4874
# Epoch 4/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 41s 18ms/step - loss: 12.6189 - root_mean_squared_error: 3.5523 - val_loss: 11.9731 - val_root_mean_squared_error: 3.4602
# Epoch 5/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 41s 18ms/step - loss: 12.4268 - root_mean_squared_error: 3.5252 - val_loss: 12.4164 - val_root_mean_squared_error: 3.5237
# Epoch 6/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 41s 18ms/step - loss: 12.2979 - root_mean_squared_error: 3.5068 - val_loss: 12.0961 - val_root_mean_squared_error: 3.4779
# Epoch 7/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 41s 18ms/step - loss: 12.0946 - root_mean_squared_error: 3.4777 - val_loss: 12.0445 - val_root_mean_squared_error: 3.4705
# Epoch 8/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 41s 18ms/step - loss: 11.9832 - root_mean_squared_error: 3.4617 - val_loss: 11.9209 - val_root_mean_squared_error: 3.4527
# Epoch 9/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 41s 18ms/step - loss: 11.8882 - root_mean_squared_error: 3.4479 - val_loss: 11.7813 - val_root_mean_squared_error: 3.4324
# Epoch 10/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 41s 18ms/step - loss: 11.7818 - root_mean_squared_error: 3.4325 - val_loss: 11.8533 - val_root_mean_squared_error: 3.4429
# Epoch 11/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 41s 18ms/step - loss: 11.6257 - root_mean_squared_error: 3.4097 - val_loss: 11.8408 - val_root_mean_squared_error: 3.4411
# Epoch 12/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 41s 18ms/step - loss: 11.5100 - root_mean_squared_error: 3.3926 - val_loss: 12.1452 - val_root_mean_squared_error: 3.4850
# Epoch 13/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 41s 18ms/step - loss: 11.3757 - root_mean_squared_error: 3.3728 - val_loss: 11.8706 - val_root_mean_squared_error: 3.4454
# Epoch 14/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 41s 18ms/step - loss: 11.3036 - root_mean_squared_error: 3.3621 - val_loss: 11.7162 - val_root_mean_squared_error: 3.4229
# Epoch 15/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 41s 18ms/step - loss: 11.0763 - root_mean_squared_error: 3.3281 - val_loss: 12.0842 - val_root_mean_squared_error: 3.4762
# Epoch 16/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 41s 18ms/step - loss: 10.9526 - root_mean_squared_error: 3.3095 - val_loss: 12.1598 - val_root_mean_squared_error: 3.4871
# Epoch 17/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 41s 18ms/step - loss: 10.8147 - root_mean_squared_error: 3.2886 - val_loss: 12.2540 - val_root_mean_squared_error: 3.5006
# Epoch 18/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 41s 18ms/step - loss: 10.6771 - root_mean_squared_error: 3.2676 - val_loss: 12.1363 - val_root_mean_squared_error: 3.4837
# Epoch 19/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 41s 18ms/step - loss: 10.5158 - root_mean_squared_error: 3.2428 - val_loss: 12.4428 - val_root_mean_squared_error: 3.5274
# Epoch 20/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 41s 18ms/step - loss: 10.3566 - root_mean_squared_error: 3.2182 - val_loss: 12.6241 - val_root_mean_squared_error: 3.5530
# Epoch 21/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 41s 18ms/step - loss: 10.2065 - root_mean_squared_error: 3.1948 - val_loss: 12.9117 - val_root_mean_squared_error: 3.5933
# Epoch 22/100
# 2238/2238 ━━━━━━━━━━━━━━━━━━━━ 41s 18ms/step - loss: 10.0571 - root_mean_squared_error: 3.1713 - val_loss: 12.6456 - val_root_mean_squared_error: 3.5561
# Epoch 22: early stopping
# ...
# Epoch 15/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 69s 62ms/step - loss: 12.3397 - root_mean_squared_error: 3.5128 - val_loss: 12.3953 - val_root_mean_squared_error: 3.5207
# Epoch 16/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 69s 62ms/step - loss: 12.2071 - root_mean_squared_error: 3.4939 - val_loss: 12.0648 - val_root_mean_squared_error: 3.4734
# Epoch 17/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 69s 62ms/step - loss: 12.0907 - root_mean_squared_error: 3.4772 - val_loss: 12.1468 - val_root_mean_squared_error: 3.4852
# Epoch 18/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 11.9745 - root_mean_squared_error: 3.4604 - val_loss: 12.2509 - val_root_mean_squared_error: 3.5001
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 10.
#
# --- Rodada 34/36 ---
#
# --- Treinando com config: {'MAX_OUTPUT_LEN': 40, 'EPOCHS': 100, 'LATENT_DIM': 512, 'BATCH_SIZE': 128, 'LEARNING_RATE': 0.0005, 'DROPOUT_RATE': 0.2} ---
# Epoch 1/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 72s 63ms/step - loss: 27.3723 - root_mean_squared_error: 5.2319 - val_loss: 13.7996 - val_root_mean_squared_error: 3.7148
# Epoch 2/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 69s 62ms/step - loss: 13.5610 - root_mean_squared_error: 3.6825 - val_loss: 12.5678 - val_root_mean_squared_error: 3.5451
# Epoch 3/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 69s 62ms/step - loss: 12.8960 - root_mean_squared_error: 3.5911 - val_loss: 12.4087 - val_root_mean_squared_error: 3.5226
# Epoch 4/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 69s 62ms/step - loss: 12.5569 - root_mean_squared_error: 3.5436 - val_loss: 12.6438 - val_root_mean_squared_error: 3.5558
# Epoch 5/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 12.3840 - root_mean_squared_error: 3.5191 - val_loss: 12.3668 - val_root_mean_squared_error: 3.5167
# Epoch 6/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 12.2062 - root_mean_squared_error: 3.4937 - val_loss: 11.9976 - val_root_mean_squared_error: 3.4638
# Epoch 7/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 12.1182 - root_mean_squared_error: 3.4811 - val_loss: 12.0424 - val_root_mean_squared_error: 3.4702
# Epoch 8/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 11.9702 - root_mean_squared_error: 3.4598 - val_loss: 12.0235 - val_root_mean_squared_error: 3.4675
# Epoch 9/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 11.8488 - root_mean_squared_error: 3.4422 - val_loss: 11.9577 - val_root_mean_squared_error: 3.4580
# Epoch 10/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 11.7359 - root_mean_squared_error: 3.4258 - val_loss: 11.8096 - val_root_mean_squared_error: 3.4365
# Epoch 11/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 11.6021 - root_mean_squared_error: 3.4062 - val_loss: 11.9436 - val_root_mean_squared_error: 3.4559
# Epoch 12/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 11.5206 - root_mean_squared_error: 3.3942 - val_loss: 12.1376 - val_root_mean_squared_error: 3.4839
# Epoch 13/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 11.3984 - root_mean_squared_error: 3.3762 - val_loss: 11.9312 - val_root_mean_squared_error: 3.4542
# Epoch 14/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 11.3152 - root_mean_squared_error: 3.3638 - val_loss: 11.7710 - val_root_mean_squared_error: 3.4309
# Epoch 15/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 11.1837 - root_mean_squared_error: 3.3442 - val_loss: 11.9443 - val_root_mean_squared_error: 3.4560
# Epoch 16/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 11.0505 - root_mean_squared_error: 3.3242 - val_loss: 11.9023 - val_root_mean_squared_error: 3.4500
# Epoch 17/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 10.9197 - root_mean_squared_error: 3.3045 - val_loss: 11.9949 - val_root_mean_squared_error: 3.4634
# Epoch 18/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 10.7668 - root_mean_squared_error: 3.2813 - val_loss: 12.1389 - val_root_mean_squared_error: 3.4841
# Epoch 19/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 10.6267 - root_mean_squared_error: 3.2599 - val_loss: 12.0192 - val_root_mean_squared_error: 3.4669
# Epoch 20/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 10.4720 - root_mean_squared_error: 3.2361 - val_loss: 12.5402 - val_root_mean_squared_error: 3.5412
# Epoch 21/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 10.3311 - root_mean_squared_error: 3.2142 - val_loss: 12.4563 - val_root_mean_squared_error: 3.5294
# Epoch 22/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 10.1446 - root_mean_squared_error: 3.1851 - val_loss: 12.4285 - val_root_mean_squared_error: 3.5254
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 14.
#
# --- Rodada 35/36 ---
#
# --- Treinando com config: {'MAX_OUTPUT_LEN': 40, 'EPOCHS': 100, 'LATENT_DIM': 512, 'BATCH_SIZE': 128, 'LEARNING_RATE': 0.0005, 'DROPOUT_RATE': 0.4} ---
# Epoch 1/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 72s 63ms/step - loss: 28.2649 - root_mean_squared_error: 5.3165 - val_loss: 13.5897 - val_root_mean_squared_error: 3.6864
# Epoch 2/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 69s 62ms/step - loss: 13.8848 - root_mean_squared_error: 3.7262 - val_loss: 12.6754 - val_root_mean_squared_error: 3.5603
# Epoch 3/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 13.1900 - root_mean_squared_error: 3.6318 - val_loss: 12.4567 - val_root_mean_squared_error: 3.5294
# Epoch 4/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 12.8375 - root_mean_squared_error: 3.5830 - val_loss: 12.2283 - val_root_mean_squared_error: 3.4969
# Epoch 5/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 12.6556 - root_mean_squared_error: 3.5575 - val_loss: 12.1129 - val_root_mean_squared_error: 3.4804
# Epoch 6/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 12.4854 - root_mean_squared_error: 3.5335 - val_loss: 12.0141 - val_root_mean_squared_error: 3.4661
# Epoch 7/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 12.3269 - root_mean_squared_error: 3.5110 - val_loss: 11.9004 - val_root_mean_squared_error: 3.4497
# Epoch 8/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 12.2032 - root_mean_squared_error: 3.4933 - val_loss: 11.7327 - val_root_mean_squared_error: 3.4253
# Epoch 9/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 12.0702 - root_mean_squared_error: 3.4742 - val_loss: 12.0489 - val_root_mean_squared_error: 3.4712
# Epoch 10/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 12.0020 - root_mean_squared_error: 3.4644 - val_loss: 11.9664 - val_root_mean_squared_error: 3.4592
# Epoch 11/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 11.8722 - root_mean_squared_error: 3.4456 - val_loss: 11.7446 - val_root_mean_squared_error: 3.4270
# Epoch 12/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 11.7483 - root_mean_squared_error: 3.4276 - val_loss: 11.7932 - val_root_mean_squared_error: 3.4341
# Epoch 13/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 11.6150 - root_mean_squared_error: 3.4081 - val_loss: 12.1472 - val_root_mean_squared_error: 3.4853
# Epoch 14/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 11.5410 - root_mean_squared_error: 3.3972 - val_loss: 12.2518 - val_root_mean_squared_error: 3.5003
# Epoch 15/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 11.3969 - root_mean_squared_error: 3.3759 - val_loss: 11.8964 - val_root_mean_squared_error: 3.4491
# Epoch 16/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 11.2923 - root_mean_squared_error: 3.3604 - val_loss: 11.9919 - val_root_mean_squared_error: 3.4629
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 8.
#
# --- Rodada 36/36 ---
#
# --- Treinando com config: {'MAX_OUTPUT_LEN': 40, 'EPOCHS': 100, 'LATENT_DIM': 512, 'BATCH_SIZE': 128, 'LEARNING_RATE': 0.0005, 'DROPOUT_RATE': 0.6} ---
# Epoch 1/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 72s 63ms/step - loss: 28.8402 - root_mean_squared_error: 5.3703 - val_loss: 14.4643 - val_root_mean_squared_error: 3.8032
# Epoch 2/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 14.5229 - root_mean_squared_error: 3.8109 - val_loss: 12.8179 - val_root_mean_squared_error: 3.5802
# Epoch 3/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 63ms/step - loss: 13.7747 - root_mean_squared_error: 3.7114 - val_loss: 12.4980 - val_root_mean_squared_error: 3.5352
# Epoch 4/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 63ms/step - loss: 13.4407 - root_mean_squared_error: 3.6662 - val_loss: 12.3378 - val_root_mean_squared_error: 3.5125
# Epoch 5/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 13.2785 - root_mean_squared_error: 3.6440 - val_loss: 12.4262 - val_root_mean_squared_error: 3.5251
# Epoch 6/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 63ms/step - loss: 13.0626 - root_mean_squared_error: 3.6142 - val_loss: 12.1276 - val_root_mean_squared_error: 3.4825
# Epoch 7/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 12.8953 - root_mean_squared_error: 3.5910 - val_loss: 12.1635 - val_root_mean_squared_error: 3.4876
# Epoch 8/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 12.8271 - root_mean_squared_error: 3.5815 - val_loss: 12.0479 - val_root_mean_squared_error: 3.4710
# Epoch 9/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 63ms/step - loss: 12.7480 - root_mean_squared_error: 3.5704 - val_loss: 11.9008 - val_root_mean_squared_error: 3.4497
# Epoch 10/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 12.5891 - root_mean_squared_error: 3.5481 - val_loss: 11.9571 - val_root_mean_squared_error: 3.4579
# Epoch 11/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 12.5028 - root_mean_squared_error: 3.5359 - val_loss: 11.9629 - val_root_mean_squared_error: 3.4587
# Epoch 12/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 12.4500 - root_mean_squared_error: 3.5285 - val_loss: 11.8114 - val_root_mean_squared_error: 3.4368
# Epoch 13/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 12.3167 - root_mean_squared_error: 3.5095 - val_loss: 11.9824 - val_root_mean_squared_error: 3.4616
# Epoch 14/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 12.1773 - root_mean_squared_error: 3.4896 - val_loss: 11.8938 - val_root_mean_squared_error: 3.4487
# Epoch 15/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 12.0689 - root_mean_squared_error: 3.4740 - val_loss: 12.0285 - val_root_mean_squared_error: 3.4682
# Epoch 16/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 11.9604 - root_mean_squared_error: 3.4584 - val_loss: 11.9634 - val_root_mean_squared_error: 3.4588
# Epoch 17/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 11.9088 - root_mean_squared_error: 3.4509 - val_loss: 12.2537 - val_root_mean_squared_error: 3.5005
# Epoch 18/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 11.7503 - root_mean_squared_error: 3.4279 - val_loss: 12.0250 - val_root_mean_squared_error: 3.4677
# Epoch 19/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 11.6171 - root_mean_squared_error: 3.4084 - val_loss: 12.0482 - val_root_mean_squared_error: 3.4710
# Epoch 20/100
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 70s 62ms/step - loss: 11.4854 - root_mean_squared_error: 3.3890 - val_loss: 12.6271 - val_root_mean_squared_error: 3.5535
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 12.
#
# --- Grid Search Concluído ---
# Melhores combinações de hiperparâmetros (ordenado pela menor perda de validação):
#         score                                            history  LATENT_DIM  \
# 1   11.690961  <keras.src.callbacks.history.History object at...         128
# 31  11.691329  <keras.src.callbacks.history.History object at...         512
# 30  11.693590  <keras.src.callbacks.history.History object at...         512
# 28  11.705330  <keras.src.callbacks.history.History object at...         512
# 22  11.713532  <keras.src.callbacks.history.History object at...         256
# 12  11.716249  <keras.src.callbacks.history.History object at...         256
# 34  11.732687  <keras.src.callbacks.history.History object at...         512
# 17  11.743325  <keras.src.callbacks.history.History object at...         256
# 25  11.744740  <keras.src.callbacks.history.History object at...         512
# 16  11.746751  <keras.src.callbacks.history.History object at...         256
# 18  11.766438  <keras.src.callbacks.history.History object at...         256
# 33  11.771028  <keras.src.callbacks.history.History object at...         512
# 6   11.777606  <keras.src.callbacks.history.History object at...         128
# 4   11.781000  <keras.src.callbacks.history.History object at...         128
# 13  11.781312  <keras.src.callbacks.history.History object at...         256
# 26  11.793793  <keras.src.callbacks.history.History object at...         512
# 32  11.796597  <keras.src.callbacks.history.History object at...         512
# 15  11.796683  <keras.src.callbacks.history.History object at...         256
# 19  11.798474  <keras.src.callbacks.history.History object at...         256
# 24  11.800792  <keras.src.callbacks.history.History object at...         512
# 20  11.810601  <keras.src.callbacks.history.History object at...         256
# 27  11.810934  <keras.src.callbacks.history.History object at...         512
# 35  11.811364  <keras.src.callbacks.history.History object at...         512
# 3   11.815066  <keras.src.callbacks.history.History object at...         128
# 14  11.821928  <keras.src.callbacks.history.History object at...         256
# 21  11.822694  <keras.src.callbacks.history.History object at...         256
# 0   11.831972  <keras.src.callbacks.history.History object at...         128
# 29  11.854058  <keras.src.callbacks.history.History object at...         512
# 10  11.858258  <keras.src.callbacks.history.History object at...         128
# 8   11.889174  <keras.src.callbacks.history.History object at...         128
# 23  11.909893  <keras.src.callbacks.history.History object at...         256
# 9   11.909957  <keras.src.callbacks.history.History object at...         128
# 7   11.915521  <keras.src.callbacks.history.History object at...         128
# 2   11.924112  <keras.src.callbacks.history.History object at...         128
# 5   11.954847  <keras.src.callbacks.history.History object at...         128
# 11  12.024545  <keras.src.callbacks.history.History object at...         128
#
#     BATCH_SIZE  LEARNING_RATE  DROPOUT_RATE
# 1           64         0.0010           0.4
# 31         128         0.0010           0.4
# 30         128         0.0010           0.2
# 28          64         0.0005           0.4
# 22         128         0.0005           0.4
# 12          64         0.0010           0.2
# 34         128         0.0005           0.4
# 17          64         0.0005           0.6
# 25          64         0.0010           0.4
# 16          64         0.0005           0.4
# 18         128         0.0010           0.2
# 33         128         0.0005           0.2
# 6          128         0.0010           0.2
# 4           64         0.0005           0.4
# 13          64         0.0010           0.4
# 26          64         0.0010           0.6
# 32         128         0.0010           0.6
# 15          64         0.0005           0.2
# 19         128         0.0010           0.4
# 24          64         0.0010           0.2
# 20         128         0.0010           0.6
# 27          64         0.0005           0.2
# 35         128         0.0005           0.6
# 3           64         0.0005           0.2
# 14          64         0.0010           0.6
# 21         128         0.0005           0.2
# 0           64         0.0010           0.2
# 29          64         0.0005           0.6
# 10         128         0.0005           0.4
# 8          128         0.0010           0.6
# 23         128         0.0005           0.6
# 9          128         0.0005           0.2
# 7          128         0.0010           0.4
# 2           64         0.0010           0.6
# 5           64         0.0005           0.6
# 11         128         0.0005           0.6
#
# Resultados do Grid Search salvos em 'grid_search_results.csv'

# %%
plot_training_history(history)
